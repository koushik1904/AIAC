# %% [markdown]
# <a href="https://colab.research.google.com/github/koushik1904/AIAC/blob/main/AiLab_19_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab Question 1: Sorting Algorithm Translation
# You are part of a multinational development team. The backend is written in
# Java, but a new module requires a Python implementation of the same
# algorithm for integration with a data science pipeline.

# %% [markdown]
# Task 1: Use AI-assisted coding to translate a given Java bubble sort
# program into Python. Verify that the translated code works correctly.

# %% [markdown]
# prompt:Convert this Java bubble sort program into Python and make sure the Python code runs correctly with the same output as the Java version.

# %%
def bubbleSort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Test case
arr = [64, 34, 25, 12, 22, 11, 90]
bubbleSort(arr)
print("Sorted array is:")
for i in range(len(arr)):
    print("%d" % arr[i]),
# Out:
# Sorted array is:
# 11
# 12
# 22
# 25
# 34
# 64
# 90

# %% [markdown]
# Task 2: Introduce errors in the Python version to check if the input list
# is empty or contains non-numeric values

# %% [markdown]
# Prompt:def bubbleSort(arr):
#     n = len(arr)
#     for i in range(n - 1):
#         for j in range(0, n - i - 1):
#             if arr[j] > arr[j + 1]:
#                 arr[j], arr[j + 1] = arr[j + 1], arr[j]
#
# # Test case
# arr = [64, 34, 25, 12, 22, 11, 90]
# bubbleSort(arr)
# print("Sorted array is:")
# for i in range(len(arr)):
#     print("%d" % arr[i]), by using this code ,generate a better version of it that it shows the errors like the input list is empty or containing non-numerical values

# %%
def bubbleSort(arr):
    if not arr:
        print("Error: Input list is empty.")
        return

    for item in arr:
        if not isinstance(item, (int, float)):
            print(f"Error: Input list contains non-numeric value: {item}")
            return

    n = len(arr)
    for i in range(n - 1):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Test cases
print("Test case 1: Valid list")
arr1 = [64, 34, 25, 12, 22, 11, 90]
bubbleSort(arr1)
print("Sorted array is:")
for i in range(len(arr1)):
    print("%d" % arr1[i]),
print("\n")

print("Test case 2: Empty list")
arr2 = []
bubbleSort(arr2)
print("\n")

print("Test case 3: List with non-numeric value")
arr3 = [64, 34, "hello", 12, 22, 11, 90]
bubbleSort(arr3)
# Out:
# Test case 1: Valid list
# Sorted array is:
# 11
# 12
# 22
# 25
# 34
# 64
# 90
#
#
# Test case 2: Empty list
# Error: Input list is empty.
#
#
# Test case 3: List with non-numeric value
# Error: Input list contains non-numeric value: hello

# %% [markdown]
# Explaination:def bubbleSort(arr):: This line defines the function bubbleSort that takes one argument, arr, which is expected to be a list.
# if not arr:: This is the first error handling check. It checks if the input list arr is empty. If it is, it prints an error message and the function returns without attempting to sort.
# for item in arr:: This loop iterates through each item in the input list arr.
# if not isinstance(item, (int, float)):: This is the second error handling check. It checks if the current item is not an integer (int) or a floating-point number (float). If it's not a number, it prints an error message indicating the non-numeric value and the function returns.
# n = len(arr): If the input list is not empty and contains only numbers, this line gets the number of elements in the list and assigns it to the variable n.
# for i in range(n - 1):: This is the outer loop of the bubble sort algorithm. It iterates n-1 times. In each iteration, the largest unsorted element "bubbles up" to its correct position.
# for j in range(0, n - i - 1):: This is the inner loop. It iterates through the unsorted part of the list. The range decreases in each outer loop iteration because the elements at the end of the list are already sorted.
# if arr[j] > arr[j + 1]:: This line compares adjacent elements in the list.
# arr[j], arr[j + 1] = arr[j + 1], arr[j]: If the element at index j is greater than the element at index j+1, this line swaps their positions.
# The remaining lines are test cases that demonstrate how to use the bubbleSort function with a valid list, an empty list, and a list containing a non-numeric value, showing the output for each scenario.

# %% [markdown]
# Lab Question 2: File Handling Translation
# A company’s legacy codebases stores and processes files in C++, but the
# analytics team needs an equivalent program in JavaScript (Node.js) for
# integration with a web dashboard.

# %% [markdown]
# Task 1: Translate a given C++ file read-and-write program into
# JavaScript using AI assistance. Ensure the script reads a text file and
# writes processed output to a new file.

# %% [markdown]
# Prompt:Translate a C++ file read-and-write program into JavaScript using AI assistance.
# Ensure the JavaScript code reads a text file, processes its content, and writes the output to a new file.

# %%
# %%writefile fileio.js
# const fs = require('fs');
# const inputFile = 'input.txt';
# const outputFile = 'output.txt';
# fs.writeFileSync(inputFile, 'Hello from Node!', 'utf8');
# fs.readFile(inputFile, 'utf8', (err, data) => {
#     if (err) return console.error(err);
#     fs.writeFile(outputFile, data.toUpperCase(), 'utf8', (err) => {
#         if (err) return console.error(err);
#         console.log("File processed successfully.");
#     });
# });
# Out:
# Overwriting fileio.js

# %%
# !node fileio.js
# Out:
# File processed successfully.

# %% [markdown]
# Task 2: Add error handling in the JavaScript version to gracefully handle
# missing files or permission errors.

# %% [markdown]
# Prompt:%%writefile fileio.js
# const fs = require('fs');
# const inputFile = 'input.txt';
# const outputFile = 'output.txt';
# fs.writeFileSync(inputFile, 'Hello from Node!', 'utf8');
# fs.readFile(inputFile, 'utf8', (err, data) => {
#     if (err) return console.error(err);
#     fs.writeFile(outputFile, data.toUpperCase(), 'utf8', (err) => {
#         if (err) return console.error(err);
#         console.log("File processed successfully.");
#     });
# });
# give me improved code by adding error handling to handle missing files or permission errors

# %%
# %%writefile fileio.js
# const fs = require('fs');
# const inputFile = 'input.txt';
# const outputFile = 'output.txt';
#
# // Ensure the input file exists or create it
# if (!fs.existsSync(inputFile)) {
#     try {
#         fs.writeFileSync(inputFile, 'This is a default input.', 'utf8');
#         console.log(`Created default input file: ${inputFile}`);
#     } catch (writeErr) {
#         console.error(`Error creating input file ${inputFile}:`, writeErr);
#         // Exit if we can't even create the input file
#         process.exit(1);
#     }
# }
#
#
# fs.readFile(inputFile, 'utf8', (err, data) => {
#     if (err) {
#         if (err.code === 'ENOENT') {
#             console.error(`Error: Input file not found at ${inputFile}`);
#         } else if (err.code === 'EACCES') {
#             console.error(`Error: Permission denied to read file ${inputFile}`);
#         } else {
#             console.error("Error reading input file:", err);
#         }
#         return; // Stop execution if file reading fails
#     }
#
#     // Process the content (e.g., convert to uppercase)
#     const processedContent = data.toUpperCase();
#
#     fs.writeFile(outputFile, processedContent, 'utf8', (err) => {
#         if (err) {
#             if (err.code === 'EACCES') {
#                 console.error(`Error: Permission denied to write to file ${outputFile}`);
#             } else {
#                 console.error("Error writing output file:", err);
#             }
#             return; // Stop execution if file writing fails
#         }
#         console.log("File processed successfully.");
#     });
# });
# Out:
# Overwriting fileio.js

# %%
# !node fileio.js
# Out:
# File processed successfully.

# %% [markdown]
# Explaination:const fs = require('fs');: This line imports the fs module, providing file system functionalities.
# const inputFile = 'input.txt'; and const outputFile = 'output.txt';: These lines define the names for the input and output files.
# if (!fs.existsSync(inputFile)) { ... }: This is a proactive check to see if the inputFile exists.
# fs.existsSync() synchronously checks if a file or directory exists.
# If the input file does NOT exist, the code enters the if block.
# try { fs.writeFileSync(inputFile, 'This is a default input.', 'utf8'); console.log(...); } catch (writeErr) { ... }: Inside the if block, a try...catch block is used to attempt to create the input file if it's missing.
# fs.writeFileSync() synchronously writes data to a file. If the file doesn't exist, it's created.
# If the file is successfully created, a message is logged.
# If an error occurs during file creation (e.g., permission issues in the directory), the catch block is executed.
# console.error(...): An error message is logged.
# process.exit(1);: The Node.js process is exited with an error code (1), indicating that the script could not proceed because the input file couldn't be created.
# fs.readFile(inputFile, 'utf8', (err, data) => { ... });: This is the asynchronous file reading operation.
# The callback function receives an err object if an error occurs and the data if successful.
# if (err) { ... }: This block handles errors that occur during fs.readFile.
# if (err.code === 'ENOENT') { ... }: Specifically checks if the error code is ENOENT, which means "Error NO ENTry" (file or directory not found). This handles cases where the file might have been deleted between the existsSync check and readFile call, or if the initial existsSync check failed for some reason and the file wasn't created.
# else if (err.code === 'EACCES') { ... }: Checks if the error code is EACCES, meaning "Error ACCess" (permission denied). This handles cases where the script doesn't have the necessary permissions to read the input file.
# else { ... }: Catches any other types of errors that might occur during reading.
# return;: If any reading error occurs, the callback function returns, stopping further execution of the file processing logic for this read operation.
# const processedContent = data.toUpperCase();: If the file is read successfully, the content is converted to uppercase. This is the processing step.
# fs.writeFile(outputFile, processedContent, 'utf8', (err) => { ... });: This is the asynchronous file writing operation.
# The callback function receives an err object if an error occurs.
# if (err) { ... }: This block handles errors that occur during fs.writeFile.
# if (err.code === 'EACCES') { ... }: Checks if the error code is EACCES, handling cases where the script doesn't have permission to write to the output file or directory.
# else { ... }: Catches any other types of errors during writing.
# return;: If any writing error occurs, the callback function returns, stopping the success message from being logged.
# console.log("File processed successfully.");: If both reading and writing complete without errors, this success message is printed.

# %% [markdown]
# Lab Question 3: API Call Translation
# Your team developed a prototype in Python to fetch weather data from an API,
# but the production environment only supports Java

# %% [markdown]
# Task 1: Translate the Python script (that makes an API call and prints
# the response) into Java using AI-assisted coding. Ensure equivalent
# functionality

# %% [markdown]
# Prompt:Translate a Python script that makes an API call and prints the response into Java using AI-assisted coding.
# Ensure the Java program performs the same API request and prints the response with equivalent functionality.

# %%
import java.net.URI;
import java.net.http.HttpClient;
import java.net.http.HttpRequest;
import java.net.http.HttpResponse;

public class ApiCall {
    public static void main(String[] args) {
        HttpClient client = HttpClient.newHttpClient();
        String url = "https://jsonplaceholder.typicode.com/posts/1";

        HttpRequest request = HttpRequest.newBuilder()
                .uri(URI.create(url))
                .build();

        try {
            HttpResponse<String> response = client.send(request, HttpResponse.BodyHandlers.ofString());

            System.out.println("API Response:");
            System.out.println(response.body());

        } catch (Exception e) {
            System.err.println("Error making API call: " + e.getMessage());
            e.printStackTrace();
        }
    }
}
# Out:
# Writing ApiCall.java

# %%
# !javac ApiCall.java
# !java ApiCall
# Out:
# /bin/bash: line 1: javac: command not found
# /bin/bash: line 1: java: command not found

# %% [markdown]
# Task 2: Add proper error handling in the Java version for cases such as
# invalid API key, request timeout, or no internet connection.

# %% [markdown]
# Prompt:%%writefile ApiCall.java
# import java.net.URI;
# import java.net.http.HttpClient;
# import java.net.http.HttpRequest;
# import java.net.http.HttpResponse;
#
# public class ApiCall {
#     public static void main(String[] args) {
#         HttpClient client = HttpClient.newHttpClient();
#         String url = "https://jsonplaceholder.typicode.com/posts/1";
#
#         HttpRequest request = HttpRequest.newBuilder()
#                 .uri(URI.create(url))
#                 .build();
#
#         try {
#             HttpResponse<String> response = client.send(request, HttpResponse.BodyHandlers.ofString());
#             System.out.println("API Response:");
#             System.out.println(response.body());
#         } catch (Exception e) {
#             System.err.println("Error making API call: " + e.getMessage());
#             e.printStackTrace();
#         }
#     }
# }
# improve the code by adding error handling cases such as invalid api key,request time out or no internet connection

# %%
# !apt-get install openjdk-17-jdk -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core ca-certificates-java fonts-dejavu-core fonts-dejavu-extra
#   gsettings-desktop-schemas java-common libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libpcsclite1 librsvg2-common libxcomposite1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless
#   session-migration x11-utils
# Suggested packages:
#   default-jre gvfs pcscd libxt-doc openjdk-17-demo openjdk-17-source visualvm
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core ca-certificates-java fonts-dejavu-core fonts-dejavu-extra
# ...

# %%
# %%writefile ApiCall.java
# import java.io.IOException;
# import java.net.URI;
# import java.net.http.HttpClient;
# import java.net.http.HttpRequest;
# import java.net.http.HttpResponse;
# import java.net.ConnectException;
# import java.net.UnknownHostException;
# import java.net.http.HttpTimeoutException;
# import java.time.Duration; // Import Duration class
#
# public class ApiCall {
#     public static void main(String[] args) {
#         // Configure HttpClient with a timeout
#         HttpClient client = HttpClient.newBuilder()
#                 .connectTimeout(Duration.ofSeconds(10)) // Set a connect timeout
#                 .build();
#
#         String url = "https://jsonplaceholder.typicode.com/posts/1"; // Example URL
#
#         HttpRequest request = HttpRequest.newBuilder()
#                 .uri(URI.create(url))
#                 .timeout(Duration.ofSeconds(15)) // Set a request timeout
#                 .build();
#
#         try {
#             HttpResponse<String> response = client.send(request, HttpResponse.BodyHandlers.ofString());
#
#             // Check for non-success HTTP status codes
#             if (response.statusCode() >= 400) {
#                 System.err.println("Error: API returned status code " + response.statusCode());
#                 System.err.println("Response body: " + response.body()); // May contain details about invalid key, etc.
#             } else {
#                 System.out.println("API Response:");
#                 System.out.println(response.body());
#             }
#
#         } catch (ConnectException e) {
#             System.err.println("Error: Could not connect to the API. Check internet connection and URL.");
#             e.printStackTrace();
#         } catch (UnknownHostException e) {
#              System.err.println("Error: Unknown host. Check the URL for typos.");
#              e.printStackTrace();
#         } catch (HttpTimeoutException e) {
#             System.err.println("Error: Request timed out.");
#             e.printStackTrace();
#         } catch (IOException e) {
#             System.err.println("Error during API call (IO issue): " + e.getMessage());
#             e.printStackTrace();
#         } catch (InterruptedException e) {
#             System.err.println("Error: API call was interrupted.");
#             e.printStackTrace();
#             Thread.currentThread().interrupt(); // Restore the interrupted status
#         } catch (Exception e) {
#             System.err.println("An unexpected error occurred: " + e.getMessage());
#             e.printStackTrace();
#         }
#     }
# }
# Out:
# Overwriting ApiCall.java

# %%
# !javac ApiCall.java

# %%
# !java ApiCall
# Out:
# API Response:
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %% [markdown]
# Explaination:import ...: These lines import necessary classes for making HTTP requests, handling URIs, and managing time durations.
# public class ApiCall { ... }: This defines a public class named ApiCall, which is the standard entry point for a Java application.
# public static void main(String[] args) { ... }: This is the main method where the program execution begins.
# HttpClient client = HttpClient.newBuilder().connectTimeout(Duration.ofSeconds(10)).build();: This creates an HttpClient instance.
# HttpClient.newBuilder() starts a builder pattern to configure the client.
# .connectTimeout(Duration.ofSeconds(10)) sets a connection timeout of 10 seconds, meaning the client will give up trying to establish a connection to the server after 10 seconds.
# .build() creates the HttpClient instance with the specified configuration.
# String url = "https://jsonplaceholder.typicode.com/posts/1";: This defines the URL for the API endpoint.
# HttpRequest request = HttpRequest.newBuilder().uri(URI.create(url)).timeout(Duration.ofSeconds(15)).build();: This creates an HttpRequest instance.
# HttpRequest.newBuilder() starts a builder pattern to configure the request.
# .uri(URI.create(url)) sets the URI for the request using the defined URL.
# .timeout(Duration.ofSeconds(15)) sets a request timeout of 15 seconds. This is the total time allowed for the entire request (including establishing connection, sending request, receiving response).
# .build() creates the HttpRequest instance.
# try { ... } catch (ConnectException e) { ... } catch (UnknownHostException e) { ... } ...: This try-catch block is used to handle potential exceptions that might occur during the API call. This is where the main error handling is implemented.
# HttpResponse<String> response = client.send(request, HttpResponse.BodyHandlers.ofString());: This line sends the HTTP request synchronously and receives the response.
# HttpResponse.BodyHandlers.ofString() specifies that the response body should be handled as a String.
# if (response.statusCode() >= 400) { ... } else { ... }: This checks the HTTP status code of the response.
# If the status code is 400 or greater (indicating a client or server error), it prints an error message including the status code and the response body (which might contain details about the error, like an invalid API key).
# If the status code is less than 400 (indicating success or redirection), it prints "API Response:" and the body of the response.
# catch (ConnectException e) { ... }: Catches exceptions that occur when a connection to the server cannot be established (e.g., no internet connection, server is down).
# catch (UnknownHostException e) { ... }: Catches exceptions that occur when the host name in the URL cannot be resolved.
# catch (HttpTimeoutException e) { ... }: Catches exceptions that occur when the request times out.
# catch (IOException e) { ... }: Catches general input/output exceptions that might occur during the request.
# catch (InterruptedException e) { ... }: Catches exceptions that occur if the thread executing the request is interrupted.
# catch (Exception e) { ... }: Catches any other unexpected exceptions.
# In each catch block, an error message is printed to the console, and the stack trace is printed for debugging purposes.
